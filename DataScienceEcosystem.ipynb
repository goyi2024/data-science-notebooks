# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular programming languages used in Data Science.
# - Identify key Data Science tools and development environments.
# - Understand the components of a typical Data Science workflow.
# - Explore basic data manipulation and analysis techniques.
# - Learn about visualization methods for presenting data insights.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1.- R programming
# 2.- Python
# 3.-SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1.- NumPy: Foundation for numerical computing with support for arrays, matrices, and mathematical functions.

# %% [markdown]
# 2.- Pandas: Essential for data cleaning, transformation, and analysis using DataFrames.

# %% [markdown]
# 3.- Matplotlib: The OG plotting library—flexible but low-level.

# %% [markdown]
# 4.- Scikit-learn: The go-to for traditional ML algorithms like regression, classification, clustering.

# %% [markdown]
# | Data Science Tools |
# |---------------------|
# | Jupyter Notebook    |
# | RStudio             |
# | Apache Zeppelin     |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
#  This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Gloria Ramos
